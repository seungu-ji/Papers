# %% [markdown]
# <a href="https://colab.research.google.com/github/viriditass/Papers/blob/main/CondConv_Conditionally_Parameterized_Convolutions_for_Efficient_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CondConv: Conditionally Parameterized Convolutions for Efficient Inference**

# %% [markdown]
# 논문 링크: https://arxiv.org/abs/1904.04971

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CondConv layer에서 convolution kernel은 위의 Figure 3과 같이 input example의 함수로 사용이 된ㄷㅏ.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
